# %% [markdown]
# ### IBM-Applied-Data-Science-Specialization Week3 Assignment-3

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
import folium
from sklearn.cluster import KMeans
import matplotlib.colors as colors

# %% [markdown]
# Reading W3_Assignment_2 output csv file

# %%
df = pd.read_csv('W3_Assignment_2.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 PostalCode      Borough  \
# 0           0             0        M1B  Scarborough
# 1           1             1        M1C  Scarborough
# 2           2             2        M1E  Scarborough
# 3           3             3        M1G  Scarborough
# 4           4             4        M1H  Scarborough
#
#                           Neighbourhood   Latitude  Longitude
# 0                         Malvern,Rouge  43.811525 -79.195517
# 1  Rouge Hill,Port Union,Highland Creek  43.785665 -79.158725
# 2       Guildwood,Morningside,West Hill  43.765815 -79.175193
# 3                                Woburn  43.768369 -79.217590
# 4                             Cedarbrae  43.769688 -79.239440

# %% [markdown]
# creating foilum map to visualize

# %%
df_map = folium.Map(location=[43.65, -79.4], zoom_start=12)

X = df['Latitude']
Y = df['Longitude']
Z = np.stack((X, Y), axis=1)

kmeans = KMeans(n_clusters=4, random_state=0).fit(Z)

clusters = kmeans.labels_
colors = ['red', 'green', 'blue', 'yellow']
df['Cluster'] = clusters

for latitude, longitude, borough, cluster in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Cluster']):
    label = folium.Popup(borough, parse_html=True)
    folium.CircleMarker(
        [latitude, longitude],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color=colors[cluster],
        fill_opacity=0.7).add_to(df_map)

# %%
df_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
